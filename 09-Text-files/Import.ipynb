# %%
filename = "009 source.txt"
file = open(filename, "r")

# %%
file = open(filename, "r")
file.read()
# Out:
# 'This is the simplest plain text file!\n'

# %%
file = open(filename, "r")
text = file.read()
text
# Out:
# 'This is the simplest plain text file!\n'

# %%
# Close the file
file.close()

# %%
with open(filename, "r") as out_file:
    text = out_file.read()
