# %%
filename = "009 source.txt"
file = open(filename, "r")

# %%
file = open(filename, "r")
file.read()
# Out:
# 'New text'

# %%
file = open(filename, "r")
text = file.read()
text
# Out:
# 'New text'

# %%
# Close the file
file.close()

# %%
with open(filename, "r") as out_file:
    out_file.read()

# %%
print(text)
# Out:
# New text

# %%
print(out_file)
# Out:
# <_io.TextIOWrapper name='009 source.txt' mode='r' encoding='utf-8'>

# %%
with open(filename, "w") as out_file:
    out_file.write("New text file\nSecond line\nThird line")

# %%
file = open(filename, "r")
text = file.read()
file.close()

# %%
print(text)
# Out:
# New text file
# Second line
# Third line

# %%
with open(filename, "r") as out_file:
    new_text = out_file.read()
print(new_text)
# Out:
# New text file
# Second line
# Third line
