# %%
import pandas as pd

# %%
numbers = pd.Series([15, 1000, 23, 45, 444])
numbers
# Out:
# 0      15
# 1    1000
# 2      23
# 3      45
# 4     444
# dtype: int64

# %%
numbers.sort_values(
    ascending=False,
)
# Out:
# 1    1000
# 4     444
# 3      45
# 2      23
# 0      15
# dtype: int64

# %%
data = pd.read_csv("Location.csv")
location_data = data.squeeze("columns").copy()
location_data.head()
# Out:
# 0     Location 3
# 1     Location 6
# 2     Location 8
# 3    Location 26
# 4    Location 34
# Name: Location, dtype: object

# %%
location_data.sort_values(ascending=True)
# Out:
# 637     Location 1
# 884     Location 1
# 465     Location 1
# 716    Location 10
# 623    Location 10
#           ...
# 482    Location 97
# 128    Location 97
# 669    Location 97
# 757    Location 98
# 372    Location 99
# Name: Location, Length: 1043, dtype: object
