# %%
import pandas as pd
import numpy as np

# %%
prices_per_category = pd.Series({"Product A": 20, "Product B": 35, "Product C": 50})
prices_per_category
# Out:
# Product A    20
# Product B    35
# Product C    50
# dtype: int64

# %%
prices_per_category.to_numpy()
# Out:
# array([20, 35, 50])

# %%
prices_per_category.values
# Out:
# array([20, 35, 50])

# %%
prices_per_category.array
# Out:
# <NumpyExtensionArray>
# [20, 35, 50]
# Length: 3, dtype: int64

# %%
type(prices_per_category.to_numpy())
# Out:
# numpy.ndarray
