# %%
s = "Price per unit"
s
# Out:
# 'Price per unit'

# %% [markdown]
# Change case of characters

# %%
s1 = s.replace("Price", "Cost")
s1
# Out:
# 'Cost per unit'

# %%
s1.split("per")
# Out:
# ['Cost ', ' unit']

# %%
s1.split(" ", maxsplit=1)
# Out:
# ['Cost', 'per unit']

# %%
s3 = "Mrs. Amy Moore"

# %%
s3.upper()
# Out:
# 'MRS. AMY MOORE'

# %%
s3.lower()
# Out:
# 'mrs. amy moore'

# %%
s3.capitalize()
# Out:
# 'Mrs. amy moore'

# %%
s3.title()
# Out:
# 'Mrs. Amy Moore'

# %%
s3 == s3.title()
# Out:
# True

# %% [markdown]
# Stripping Characters

# %%
s4 = "  Hello World     "
s4.strip()
# Out:
# 'Hello World'

# %%
s4.strip(" ")
# Out:
# 'Hello World'

# %%
s4.strip(" H")
# Out:
# 'ello World'

# %%
s4.strip(" ld")
# Out:
# 'Hello Wor'
