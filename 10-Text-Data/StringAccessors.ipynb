# %%
import pandas as pd

# %%
operational_kpis = pd.Series(["employee satisfaction rating", "employee churn rate"])

operational_kpis
# Out:
# 0    employee satisfaction rating
# 1             employee churn rate
# dtype: object

# %%
operational_kpis[0].lstrip("employee ")
# Out:
# 'satisfaction rating'

# %%
operational_kpis[0].lstrip("employee")
# Out:
# ' satisfaction rating'

# %%
operational_kpis[1].lstrip("employee")
# Out:
# ' churn rate'

# %%
pd.Series(
    [operational_kpis[0].lstrip("employee "), operational_kpis[1].lstrip("employee ")]
)
# Out:
# 0    satisfaction rating
# 1             churn rate
# dtype: object

# %%
operational_kpis.str  # string accessor

# %%
operational_kpis.str[1]  # second character of each string
# Out:
# 0    m
# 1    m
# dtype: object

# %%
operational_kpis[1]
# Out:
# 'employee churn rate'

# %%
operational_kpis.str.lstrip("employee ")  # lstrip for each element in the Series
# Out:
# 0    satisfaction rating
# 1             churn rate
# dtype: object

# %%
test_series = pd.Series(["leading_space", 34, "both"])
test_series
# Out:
# 0    leading-space
# 1               34
# 2             both
# dtype: object

# %%
test_series.str.lstrip("leading_")  # error because of non-string value
# Out:
# 0    -space
# 1       NaN
# 2      both
# dtype: object

# %%
house_prices = pd.Series(["$1,000", "$2,500", "$3,000"])
house_prices
# Out:
# 0    $1,000
# 1    $2,500
# 2    $3,000
# dtype: object

# %%
house_prices.str.contains("$")
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
time_horizon = 1, 3, 13
time_horizon
# Out:
# (1, 3, 13)

# %%
products = ["Product A", "Product B"]
products
# Out:
# ['Product A', 'Product B']

# %%
"Expected sales for a period of {0} month(s) for {1}:".format(
    time_horizon[1], products[0]
)
# Out:
# 'Expected sales for a period of 3 month(s) for Product A:'

# %%
"Expected sales for a period of {t_hor} month(s) for {prod}:".format(
    t_hor=12, prod="Product B"
)
# Out:
# 'Expected sales for a period of 12 month(s) for Product B:'
