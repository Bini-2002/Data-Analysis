# %%
import sklearn

# %%
import numpy as np

# %%
arr = [10,20,30]

a = np.max(arr)

print(a)
# Out:
# 30

# %%
np.__version__
# Out:
# '2.2.4'

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'
