# %%
import numpy as np

arr = np.array([1,2,3])

arr
# Out:
# array([1, 2, 3])

# %%
arr_1 = np.array([[1,2,3],[4,5,6]])

arr_1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# Numpy Documentation
#
# https://numpy.org/devdocs
