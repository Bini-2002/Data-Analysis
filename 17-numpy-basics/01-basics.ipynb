# %%
import numpy as np

# %%
arr_a = np.array([[1, 2, 3], [4, 5, 6]])  # Corrected array formation
arr_a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr_a[0]
# Out:
# array([1, 2, 3])

# %%
arr_a[1][1]
# Out:
# np.int64(5)

# %%
arr_a[1, 1]
# Out:
# np.int64(5)

# %%
arr_a[:, 2]
# Out:
# array([3, 6])
