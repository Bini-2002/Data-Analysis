# %%
import numpy as np

# %%
arr_b = np.array([[1, 2, 3], [4, 5, 6]])  # Corrected array formation
arr_b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr_a = np.array([7, 8, 9])  # Corrected array formation
arr_a
# Out:
# array([7, 8, 9])

# %%
arr_a + 2
# Out:
# array([ 9, 10, 11])

# %%
arr_b * 3
# Out:
# array([[ 3,  6,  9],
#        [12, 15, 18]])

# %%
list_a = [1, 2, 3]
list_a + [2]
# Out:
# [1, 2, 3, 2]

# %%
arr_a + arr_b[0]
# Out:
# array([ 8, 10, 12])

# %%
arr_a + arr_b
# Out:
# array([[ 8, 10, 12],
#        [11, 13, 15]])
