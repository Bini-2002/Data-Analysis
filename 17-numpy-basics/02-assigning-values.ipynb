# %%
import numpy as np

# %%
arr_a = np.array([[1, 2, 3], [4, 5, 6]])  # Corrected array formation
arr_a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr_a[0, 2] = 10
arr_a
# Out:
# array([[ 1,  2, 10],
#        [ 4,  5,  6]])

# %%
arr_a[1] = 6
arr_a
# Out:
# array([[ 1,  2, 10],
#        [ 6,  6,  6]])

# %%
arr_a[1] = [7, 8, 9]
arr_a
# Out:
# array([[ 1,  2, 10],
#        [ 7,  8,  9]])

# %%
arr_a = 9
arr_a
# Out:
# 9

# %%
arr_a = np.array([[1, 2, 3], [4, 5, 6]])  # Corrected array formation
arr_a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
