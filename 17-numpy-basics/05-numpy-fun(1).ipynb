# %%
import numpy as np

# %%
arr_a = np.array([1, 2, 3])
arr_a
# Out:
# array([1, 2, 3])

# %%
arr_b = np.array([[1], [2]])
arr_b
# Out:
# array([[1],
#        [2]])

# %%
matrix_c = np.array([[1, 2, 3], [4, 5, 6]])
matrix_c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
#   ## Broadcasting

# %%
np.add(arr_a, matrix_c)
# Out:
# array([[2, 4, 6],
#        [5, 7, 9]])

# %% [markdown]
# https://numpy.org/doc/stable/reference/ufuncs.html

# %% [markdown]
# ## Universal Functions
