# %% [markdown]
# Exercise 1:

# %%
import numpy as np
import pandas as pd

# %%
employees_name = pd.Series(["Amy White" , "Jack Stewart" , "Richard Lauderdale" ,"Sara Johnson"])

print(employees_name)
# Out:
# 0             Amy White
# 1          Jack Stewart
# 2    Richard Lauderdale
# 3          Sara Johnson
# dtype: object

# %%
array_age = np.array([50, 53, 35, 43])

series_age = pd.Series(array_age)

print(series_age)
# Out:
# 0    50
# 1    53
# 2    35
# 3    43
# dtype: int64

# %% [markdown]
# Exercise 2:

# %%
work_experience_years = pd.Series([5,8,10,3])
print(work_experience_years)
# Out:
# 0     5
# 1     8
# 2    10
# 3     3
# dtype: int64

# %%
print(work_experience_years.to_numpy())
# Out:
# [ 5  8 10  3]

# %%
work_experience_years.size
# Out:
# 4

# %%
work_experience_years.name = "Work Experience (Yrs.)"
